# %% [markdown]
# # Multi Agent Team Approach - With Termination Condition

# %%
import asyncio
import os
from dotenv import load_dotenv
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import (AssistantAgent)
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.teams import RoundRobinGroupChat

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %%
# Specify Agents
plot_agent = AssistantAgent(
    name= 'plot_writer',
    model_client=model_client,
    system_message="You create engaging plots for stories. Focus on being a murder mystery detective chef."
)

character_agent = AssistantAgent(
    name='character_writer',
    model_client=model_client,
    system_message="You develop characters. Describe the chefs and the murderer in detail, including their motivations and background."
)

ending_agent = AssistantAgent(
    name='ending_writer',
    model_client=model_client,
    system_message="You write engaing endings. conclude the story with a twist."
)

# %% [markdown]
# ## Termination Condition: MaxMessageTermination
# Stops after a specified number of messages have been produced including both agent and task messages

# %%
from autogen_agentchat.conditions import MaxMessageTermination

# Create termination condition
# NOTE: necessary, as max_turns only available in RoundRobinGroupChat and not other GroupChats
termination_condition = MaxMessageTermination(2)

# %%
# Establish team
team = RoundRobinGroupChat(
    participants=[plot_agent, character_agent, ending_agent],
    termination_condition=termination_condition
    #max_turns=3
)

# %%
from autogen_agentchat.base import TaskResult

# When running a script, use a async main function and call it from `asyncio.run(...)`
await team.reset()   # Reset the team for a new task

async for message in team.run_stream(task="Write a short poam about the fall season."):
    if isinstance(message, TaskResult):
        print("Stop Reason:", message.stop_reason)
    else:
        print(message)
# Out:
# id='70bb576a-4a17-42a5-bff3-11d1d39de296' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 1, 22, 13, 40, 44, 490215, tzinfo=datetime.timezone.utc) content='Write a short poam about the fall season.' type='TextMessage'
# id='e4985283-99d4-4de1-b79c-b72663790d49' source='plot_writer' models_usage=RequestUsage(prompt_tokens=38, completion_tokens=182) metadata={} created_at=datetime.datetime(2026, 1, 22, 13, 40, 51, 288019, tzinfo=datetime.timezone.utc) content="In whispers of gold and crisp, the leaves descend,  \nA tapestry woven where summer dreams end.  \nMisty breath tangles with cinnamon's charm,  \n'Tween the scent of ripe apples, fall wraps warm.  \n\nThrough woods rich with russet and auburn gleam,  \nDaylight meanders in a pumpkin spice dream.  \nPainted skies blush with twilight's soft flare,  \nWhile shadows dance in the cool autumn air.  \n\nChilled gusts rattle through branches once green,  \nScattering secrets where silence convene.  \nIn the hearth's glow, stories gently unfold,  \nAs fall's gentle grace in the heart is enfolded.  \n\nEchoes of laughter in the crisp, brisk night,  \nIn the whispers of fall, everything feels right.  \nSo as the leaves tumble, the world slows down,  \nWrapped in autumn's embrace, a vibrant crown.  " type='TextMessage'
# Stop Reason: Maximum number of messages 2 reached, current message count: 2

# %% [markdown]
# ## Multiple Termination Conditions
# Can combine termination conditions

# %%
from autogen_agentchat.conditions import TextMentionTermination

termination_condition = MaxMessageTermination(10) | TextMentionTermination('APPROVE')

# %%
# Createa new agent
review_agent = AssistantAgent(
    name = 'review_writer',
    model_client=model_client,
    system_message="You have to say 'APPROVE' once the story is complete or you will have to provide feedback"
)

# Establish team
team = RoundRobinGroupChat(
    participants=[plot_agent, character_agent, ending_agent, review_agent],
    termination_condition=termination_condition
    #max_turns=3
)

# Run
await team.reset()   # Reset the team for a new task
async for message in team.run_stream(task="Write a short poam about the fall season."):
    if isinstance(message, TaskResult):
        print("Stop Reason:", message.stop_reason)
    else:
        print(message)
# Out:
# id='7cccd5f8-632f-4286-8c1b-fb90aeacaacd' source='user' models_usage=None metadata={} created_at=datetime.datetime(2026, 1, 22, 16, 19, 20, 12745, tzinfo=datetime.timezone.utc) content='Write a short poam about the fall season.' type='TextMessage'
# id='e9292e14-656a-4c5c-8f22-7a41968b5e0b' source='plot_writer' models_usage=RequestUsage(prompt_tokens=38, completion_tokens=115) metadata={} created_at=datetime.datetime(2026, 1, 22, 16, 19, 23, 719364, tzinfo=datetime.timezone.utc) content='Autumn whispers in hues of gold,  \nLeaves rustle secrets, tales retold.  \nPumpkin spice and chimneys smoke,  \nIn chilly gusts the old trees cloak.  \n\nCrisp air bites with a gentle nudge,  \nOrchards boast of cider’s grudge.  \nWarm woolen knit and fading light,  \nStars sprinkle tales in the brisk night.  \n\nA tapestry of amber leaves,  \nWeaves a story the heart believes.  \nIn nature’s dance, a symphony,  \nFall sings its sweet soliloquy.  ' type='TextMessage'
# id='e68dc82a-e194-4a32-98c6-0dd318ee8653' source='character_writer' models_usage=RequestUsage(prompt_tokens=163, completion_tokens=599) metadata={} created_at=datetime.datetime(2026, 1, 22, 16, 19, 39, 375792, tzinfo=datetime.timezone.utc) content="In the bustling kitchen of Le Serene, a Michelin-starred restaurant nestled in the heart of a quaint European town, an enigmatic yet tragic tale unfolds involving three chefs and a sinister murderer.\n\n**Chef Anton DuVrey:**  \nAnton is the head chef and proprietor of Le Serene. In his early 50s, he carries the distinguished air of a culinary master whose career spans continents. With silver-streaked hair and piercing hazel eyes, Anton possesses a commanding presence. His meticulous nature and insistence on perfection have earned him accolades, although they sometimes intimidate his colleagues. Born into a family of chefs, Anton’s motivation is rooted in preserving his family’s culinary legacy. Behind his stern facade, Anton harbors a deep-seated fear of obsolescence, as he has seen too many illustrious chefs fade into obscurity.\n\n**Sous Chef Mariana Rossi:**  \nMariana, a fiery Italian with a flair for bold flavors, is in her late 20s. Her vibrant personality is mirrored in her dishes, known for their audacious pairings and vivid presentations. With flowing black hair and olive skin, Mariana exudes an effusive warmth that endears her to the restaurant staff. Coming from a humble background, her motivation lies in proving herself in an industry dominated by older, more experienced chefs. She dreams of opening her own restaurant someday, though her loyalty to Anton and Le Serene runs deep. Her ambition, however, sometimes clashes with Anton's traditionalist approach.\n\n**Pastry Chef Samuel LeMaire:**  \nSamuel is a reserved and introspective man in his early 40s. His delicate desserts are akin to fine art, relying on subtlety and precision. Samuel’s gentle touch is complemented by his soft-spoken nature and striking blue eyes that hide a profound depth. Born in Paris, Samuel's motivation is driven by the pursuit of beauty and harmony through food. His creations are a refuge from a tumultuous past, which includes overcoming personal struggles. Although he often keeps to himself, Samuel’s talent and dedication command respect from his peers.\n\n**The Murderer, Victor Connors:**  \nVictor, a mysterious figure in his mid-30s, is a former chef turned critic. With sharp cheekbones and an enigmatic demeanor, he easily infiltrates culinary circles. Known for his scathing reviews and unyielding standards, Victor’s motivations are veiled in obscurity. Beneath his polished exterior lies a simmering resentment towards the culinary world that once spurned him. Victor harbors a burning desire to expose the industry's darker side and seek retribution against those who wronged him. His actions are driven by a twisted sense of justice, believing that the downfall of a prestigious establishment like Le Serene will validate his vendetta.\n\nAs tensions rise in the kitchen of Le Serene, the lives of these chefs intertwine with Victor’s malevolent intentions, culminating in a gripping tale of ambition, betrayal, and the relentless pursuit of perfection." type='TextMessage'
# id='7678adc4-8a6d-4f7a-a308-c0d2dfb49ab0' source='ending_writer' models_usage=RequestUsage(prompt_tokens=763, completion_tokens=483) metadata={} created_at=datetime.datetime(2026, 1, 22, 16, 19, 53, 521982, tzinfo=datetime.timezone.utc) content='In the dim, ambient glow of Le Serene\'s kitchen, the clashing of culinary dreams and sinister plots reached a boiling point. A night that started like any other soon simmered with unnerving tension as rumors of Victor Connors\' scathing review threatened to tarnish the restaurant\'s impeccable reputation.\n\nChef Anton DuVrey, pacing frantically, contemplated how years of dedication could crumble from mere words. Sous Chef Mariana Rossi, fueled by ambition and fierce loyalty, vowed quietly to protect her mentor\'s legacy. Meanwhile, Pastry Chef Samuel LeMaire remained unusually silent, his eyes reflecting a storm of memories from a past he long wished to forget.\n\nAs the evening unfolded, the air crackled with anticipation. Victor Connors, resplendent in his deceptive charm, sat at a corner table, observing every culinary nuance with hawk-like scrutiny. His presence cast a shadow over the kitchen, tightening every nerve.\n\nIn an unexpected twist, the murderer was not who they feared but someone from within.\n\nThat evening, as Anton presented the centerpiece dish to Victor with hands that only slightly trembled, a dramatic revelation was set in motion. Victor\'s face twisted not in condemnation but in shock, and suddenly he clutched his throat and collapsed.\n\nChaos erupted as panic overtook the dining room. The chefs stood stunned, but it was Mariana who stepped forward, her eyes wide with a realization that only she harbored. She knew it was not Anton\'s dish that had caused this. Her gaze locked with Samuel, who stood at a distance, his tranquil demeanor unchanged.\n\nAs Victor was rushed from the scene, Mariana approached Samuel. In a barely audible whisper, she questioned him, "Why?"\n\nSamuel\'s eyes softened, revealing a man not driven by malice but by a promise. "Victor knew he had to taste humility," he said softly, "I just gave him a dose of reckoning, a reminder of the past he chose to forget—one that destroyed lives, including mine."\n\nIn the end, the twist was not simply about a murder but also revelation—a chance to confront demons, where Samuel gave the culinary world not a harsh critique but a chance to remember the humanity within its hollow pursuit of perfection. Anton, recognizing the underlying truth and the subtle justice, chose silence as his tribute to Samuel\'s calm yet profound victory—a bittersweet homage to the delicate balance of art and ambition.' type='TextMessage'
# id='50bb5288-6c86-4d0f-b100-e13a0fd10b6c' source='review_writer' models_usage=RequestUsage(prompt_tokens=1261, completion_tokens=3) metadata={} created_at=datetime.datetime(2026, 1, 22, 16, 19, 54, 734956, tzinfo=datetime.timezone.utc) content='APPROVE' type='TextMessage'
# Stop Reason: Text 'APPROVE' mentioned
